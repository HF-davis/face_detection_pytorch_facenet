# %%
import cv2
import requests
import base64
# -*- coding: utf-8 -*-
import numpy as np

# %%
img=cv2.imread('./val/Davis Alderete/310.png')

# %%
type(img.shape)
# Out:
# tuple

# %%
code = base64.b64encode(img)
print(code)
m=code.decode()
print(m)
# Out:
# b'...'
# ...

# %%
bytes(m,'utf-8')
# Out:
# b'...'

# %%
import json
s=json.dumps(code.decode())
type(s)
#res=requests.post("http://127.0.0.1:5000/TrainModel")
# Out:
# str

# %%
list(img.shape)
# Out:
# [480, 640, 3]

# %%
decode=base64.b64decode(code)
decoded_img=np.fromstring(decode,dtype=np.uint8)
#decoded_img=decoded_img.reshape(list(img.shape))
# Out:
# C:\Users\asus\AppData\Local\Temp/ipykernel_7244/437006122.py:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   decoded_img=np.fromstring(decode,dtype=np.uint8)

# %%
decoded_img
print(img.shape[0]*img.shape[1]*img.shape[2])
len(decoded_img)
# Out:
# 921600
# 921600

# %%
decoded_img=decoded_img.reshape(img.shape)
decoded_img
# Out:
# array([[[193, 222, 233],
#         [192, 221, 232],
#         [198, 221, 228],
#         ...,
#         [250, 253, 251],
#         [250, 253, 251],
#         [250, 253, 251]],
#
#        [[193, 222, 233],
#         [193, 222, 233],
#         [197, 223, 230],
#         ...,
#         [250, 253, 251],
#         [250, 253, 251],
#         [250, 253, 251]],
#
#        [[198, 221, 230],
#         [198, 221, 230],
#         [199, 222, 231],
#         ...,
#         [250, 253, 251],
#         [250, 253, 251],
#         [250, 253, 251]],
#
#        ...,
#
#        [[254, 255, 255],
#         [255, 255, 255],
#         [250, 255, 255],
#         ...,
#         [ 84,  60,  55],
#         [ 86,  60,  55],
#         [ 86,  60,  55]],
#
#        [[255, 254, 255],
#         [254, 253, 255],
#         [225, 228, 246],
#         ...,
#         [ 91,  60,  56],
#         [ 93,  61,  55],
#         [ 92,  59,  53]],
#
#        [[ 89,  89,  98],
#         [ 78,  78,  87],
#         [ 65,  72,  92],
# ...
